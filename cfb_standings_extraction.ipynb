# %%
import requests as r

# %%
html_2000 = r.get("https://widgets.sports-reference.com/wg.fcgi?css=1&site=cfb&url=%2Fcfb%2Fyears%2F2000-standings.html&div=div_standings")

# %%
html_2000.text
# Out:
# 'document.write(\'<div class="sr_widget" style="overflow-x:auto">\');\ndocument.write(\'<div class="sr_widget_content">\');\ndocument.write(\'<style type="text/css">\\\n.sr_widget table {\\\n  border-collapse: collapse;\\\n  font-size: 1em;\\\n}\\\n.sr_widget table td {\\\n  padding-right: 1em;\\\n}\\\n/* The basic stats table. */\\\n.sr_widget .stats_table {\\\n  border-collapse: collapse;\\\n  border: #747678 solid 1px;\\\n  font-size: .875em;\\\n  margin-bottom: 1em;\\\n  /* assorted other things */\\\n\\\n  /* For tables inside a stats_table */\\\n\\\n}\\\n.sr_widget .stats_table th, .sr_widget  .stats_table td {\\\n  border-width: 1px;\\\n  border-color: #aaaaaa;\\\n  padding: 3px;\\\n  vertical-align: inherit;\\\n}\\\n.sr_widget .stats_table th *, .sr_widget  .stats_table td * {\\\n  vertical-align: inherit;\\\n}\\\n.sr_widget .stats_table th {\\\n  background-color: #dadcde;\\\n  border-style: solid;\\\n  color:black!important;\\\n  opacity: initial;\\\n}\\\n.sr_widget .stats_
# ...
